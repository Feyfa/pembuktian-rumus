# %%
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# ambil data tips dari seaborn
df = sns.load_dataset('tips')
# print(df.head())
# print(len(df))

# %%
# 1. pisahkan fitur (X) dan label (Y)
X = df.drop('tip',axis=1) # seluruh kolom kecuali tip
Y = df['tip'] # ambil kolom tip saja
# print(X)
# print(Y)

# %%
# 2. Pemisahan data - train - test

X_train, X_test, Y_Tain, Y_Test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# print(X_train.head())
# print(len(X_train))

# %%
# print(X_test.head())
# print(len(X_test))
